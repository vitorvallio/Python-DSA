# %% [markdown]
# # Capítulo 8 - Classes

# %% [markdown]
# ## Classes

# %%
class Livro():
    def __init__(self):
        self.titulo = 'Sapiens - Uma Breve História da Humanidade'
        self.isbn = 9988888
        print("Construtor chamado para criar um objeto desta classe.")
    
def imprime(self):
    print("Foi criado o livro %s com ISBN %d" %(self.titulo, self.isbn))
# Out:
# A execução de células com 'Python 3.13.5' requer o pacote ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crie um ambiente Python</a> com os pacotes necessários.
#
# Ou instale 'ipykernel' usando o comando: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
Livro1 = Livro()

# %%
type(Livro1)

# %%
Livro1.titulo

# %%
Livro1.imprime()
