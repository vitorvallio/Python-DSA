# %% [markdown]
# # Capítulo 8 - Herança de Classes

# %% [markdown]
# ## Herança de Classes em Python

# %%
class Animal():
    def __init__(self):
        print("Animal criado.")

    def imprimir(self):
        print("Este é um animal.")

    def comer(self):
        print("Hora de comer.")

    def emitir_som(self):
        pass

# %%
class Cachorro(Animal):
    def __init__(self):
        Animal.__init__(self)
        print("Objeto Cachorro criado.")
    
    def emitir_som(self):
        print("Au au!")

# %%
class Gato(Animal):
    def __init__(self):
        Animal.__init__(self)
        print("Objeto Gato criado.")
    
    def emitir_som(self):
        print("Miau!")

# %%
rex = Cachorro()
# Out:
# Animal criado.
# Objeto Cachorro criado.

# %%
zeze = Gato()
# Out:
# Animal criado.
# Objeto Gato criado.

# %%
rex.emitir_som()
# Out:
# Au au!

# %%
zeze.emitir_som()
# Out:
# Miau!

# %%
rex.imprimir()
# Out:
# Este é um animal.
# Este é um animal.

# %%
zeze.imprimir()
# Out:
# Este é um animal.

# %%
rex.comer()
# Out:
# Hora de comer.

# %%
zeze.comer()
# Out:
# Hora de comer.

# %% [markdown]
# # FIM
