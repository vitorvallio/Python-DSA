# %% [markdown]
# # Capítulo 6 - Tratamento de Erros e Exceções

# %% [markdown]
# ## Erros e Exceções

# %%
print('Hello')
# Out:
# Hello

# %%
s = 8
8 + s
# Out:
# 16

# %%
def numDiv (num1, num2):
    resultado = num1/num2
    print(resultado)

# %%
numDiv(4,2)
# Out:
# 2.0
